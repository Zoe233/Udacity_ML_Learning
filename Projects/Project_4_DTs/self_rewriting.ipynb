# %% [markdown]
# ## Lecture and example code for decision tree unit

# %%
import sys
from class_vis import prettyPicture
from class_vis_out import output_image
from prep_terrain_data import makeTerrainData

import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
from classifyDT import classify

# %%
features_train, labels_train, features_test, labels_test = makeTerrainData()

# %%
clf = classify(features_train, labels_train)

# %%
prettyPicture(clf, features_test, labels_test)

# %%
acc = clf.score(features_test, labels_test)

# %%
def submitAccuracies():
    return {'acc':round(acc,3)}

# %%
submitAccuracies()
# Out:
# {'acc': 0.908}

# %%
from sklearn.tree import DecisionTreeClassifier
clf2 = DecisionTreeClassifier(min_samples_split=50)
clf.fit(features_train, labels_train)

acc2 = clf.score(features_test, labels_test)
print('Accuracy of min_samples_split = 50:', round(acc2, 3))
# Out:
# Accuracy of min_samples_split = 50: 0.912

# %% [markdown]
# ### 比较：
# 相比于min_sample_split=2, min_sample_split=50在分类器上的性能表现提升了0.4%。
